# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.transforms import Bbox

directory = r'RESULTS/K_MEDOIDS'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_k_medoids_RMSE')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        rmse = table['RMSE']
        filepath_random = os.path.join(directory_random, task_name + '_random_rmse_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        rmse_random = table_random['RMSE']
        df[task_name] = (rmse - rmse_random) / rmse_random

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'linear_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'linear_regression': 'linear regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rel. difference to random split test RMSE (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Clustering')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/k_medoids_RMSE_num_and_cat_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/UMAP_DECOMPOSITION'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_umap_decomposition_RMSE')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        rmse = table['RMSE']
        filepath_random = os.path.join(directory_random, task_name + '_random_rmse_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        rmse_random = table_random['RMSE']
        df[task_name] = (rmse - rmse_random) / rmse_random


df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'linear_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'linear_regression': 'linear regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rel. difference to random split test RMSE (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('UMAP decomposition')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/umap_decomposition_RMSE_num_and_cat_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/GOWER'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_gower_RMSE')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        rmse = table['RMSE']
        filepath_random = os.path.join(directory_random, task_name + '_random_rmse_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        rmse_random = table_random['RMSE']
        df[task_name] = (rmse - rmse_random) / rmse_random

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'linear_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'linear_regression': 'linear regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rel. difference to random split test RMSE (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Gower distance')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/gower_RMSE_num_and_cat_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
# Plotting the average test accuracy for all extrapolation methods
import os
import pandas as pd
import seaborn as sns

list_directories = [r'RESULTS/K_MEDOIDS', r'RESULTS/UMAP_DECOMPOSITION', r'RESULTS/GOWER']
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for directory in list_directories:
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            task_name = filename
            task_name_2 = filename.split('_')[0]
            filepath = os.path.join(directory, filename)
            table = pd.read_csv(filepath).iloc[:-2, :] 
            rmse = table['RMSE']
            filepath_random = os.path.join(directory_random, task_name_2 + '_random_rmse_results.csv')
            table_random = pd.read_csv(filepath_random).iloc[:-2, :]
            rmse_random = table_random['RMSE']
            df[task_name] = (rmse - rmse_random) / rmse_random

df.index=table['Method']
df.index.name = 'Method'
df = 100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'linear_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'linear_regression': 'linear regression', 'FTTrans': 'FT-Transformer'})
#result_df['Mean'] = 100*result_df['Mean']
#result_df['Median'] = 100*result_df['Median']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rel. difference to random split test RMSE (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Average over extrapolation techniques')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/average_over_extrapolation_techniques_RMSE_num_and_cat_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
result_df
# Out:
#               Method         Mean     Median  Standard Deviation
# 0           constant    17.769210  12.175798           22.977883
# 6  linear regression  1212.818831  20.964735         7518.564588
# 5      random forest   843.347500  12.548307         3782.568820
# 4      boosted trees  1432.068698   9.839659         6714.977861
# 7         engression  1105.293876  17.760196         4087.287617
# 1                MLP  1018.346694  29.374717         4016.792279
# 2             ResNet   255.944557  61.074628          503.584513
# 3     FT-Transformer   790.337282  17.204139         3096.166341

# %%
df
# Out:
#                    361093_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.127411
# MLP                                        -0.159702
# ResNet                                      0.922210
# FTTrans                                    -0.064244
# boosted_trees                              -0.244456
# rf                                         -0.261105
# linear_regression                           0.131107
# engression                                  0.404537
#
#                    361094_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.261158
# MLP                                       206.131126
# ResNet                                     26.971979
# FTTrans                                   147.393896
# boosted_trees                             353.524174
# rf                                        199.068713
# linear_regression                           3.063355
# engression                                216.572632
#
#                    361096_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.057481
# MLP                                        -0.051667
# ResNet                                      0.944499
# FTTrans                                     0.169481
# boosted_trees                               0.158325
# rf                                          0.204581
# linear_regression                           1.108770
# engression                                  4.638027
#
#                    361097_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.221304
# MLP                                         0.305873
# ResNet                                      0.603445
# FTTrans                                          NaN
# boosted_trees                              -0.024153
# rf                                          0.024264
# linear_regression                          28.344561
# engression                                  0.051284
#
#                    361098_k_medoids_RMSE_results.csv  \
# Method
# constant                                   -0.012317
# MLP                                         0.417718
# ResNet                                      1.386085
# FTTrans                                     1.564913
# boosted_trees                               0.252174
# rf                                          0.281053
# linear_regression                           0.696844
# engression                                  4.293887
#
#                    361099_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.133379
# MLP                                         0.881068
# ResNet                                      2.328964
# FTTrans                                     0.725483
# boosted_trees                               0.652211
# rf                                          0.919154
# linear_regression                           0.096584
# engression                                  0.866181
#
#                    361101_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.031039
# MLP                                         0.116149
# ResNet                                      0.315782
# FTTrans                                     0.140930
# boosted_trees                               0.257805
# rf                                          0.264268
# linear_regression                           0.317377
# engression                                  2.305240
#
#                    361102_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.061641
# MLP                                         0.069880
# ResNet                                      0.501810
# FTTrans                                     0.090427
# boosted_trees                               0.131427
# rf                                          0.101465
# linear_regression                           0.034500
# engression                                  0.097037
#
#                    361103_k_medoids_RMSE_results.csv  \
# Method
# constant                                    0.181602
# MLP                                         0.188433
# ResNet                                      0.248226
# FTTrans                                     0.174601
# boosted_trees                               0.196766
# rf                                          0.192945
# linear_regression                           0.233108
# engression                                  0.174306
#
#                    361104_k_medoids_RMSE_results.csv  ...  \
# Method                                                ...
# constant                                    0.166589  ...
# MLP                                        -0.137287  ...
# ResNet                                      3.645596  ...
# FTTrans                                     1.158921  ...
# boosted_trees                              -0.081143  ...
# rf                                         -0.288279  ...
# linear_regression                           0.156661  ...
# engression                                 -0.159573  ...
#
#                    361101_gower_RMSE_results.csv  \
# Method
# constant                                0.109058
# MLP                                     0.339082
# ResNet                                  0.518065
# FTTrans                                 0.219267
# boosted_trees                           0.310883
# rf                                      0.308795
# linear_regression                       0.448877
# engression                              0.337125
#
#                    361102_gower_RMSE_results.csv  \
# Method
# constant                                0.439859
# MLP                                     0.440506
# ResNet                                  1.343774
# FTTrans                                 0.698262
# boosted_trees                           0.584126
# rf                                      0.614702
# linear_regression                       0.220202
# engression                              0.410424
#
#                    361103_gower_RMSE_results.csv  \
# Method
# constant                                0.271490
# MLP                                     0.520097
# ResNet                                  0.402504
# FTTrans                                 0.206640
# boosted_trees                           0.198703
# rf                                      0.173382
# linear_regression                       0.335221
# engression                              0.180898
#
#                    361104_gower_RMSE_results.csv  \
# Method
# constant                                0.641726
# MLP                                     6.033094
# ResNet                                  8.958752
# FTTrans                                 9.896556
# boosted_trees                          11.667605
# rf                                     12.792119
# linear_regression                       2.273066
# engression                              2.680047
#
#                    361288_gower_RMSE_results.csv  \
# Method
# constant                                0.325561
# MLP                                     0.414750
# ResNet                                  0.714622
# FTTrans                                 0.007471
# boosted_trees                           0.108378
# rf                                      0.104097
# linear_regression                       0.151703
# engression                              0.025654
#
#                    361289_gower_RMSE_results.csv  \
# Method
# constant                                0.242548
# MLP                                     0.180512
# ResNet                                  0.320874
# FTTrans                                 0.179895
# boosted_trees                           0.181628
# rf                                      0.182959
# linear_regression                       0.190967
# engression                              0.174161
#
#                    361291_gower_RMSE_results.csv  \
# Method
# constant                               -0.005387
# MLP                                     0.005036
# ResNet                                  0.008127
# FTTrans                                 0.002535
# boosted_trees                          -0.002037
# rf                                      0.001366
# linear_regression                       0.005375
# engression                              0.005884
#
#                    361292_gower_RMSE_results.csv  \
# Method
# constant                                0.292272
# MLP                                     0.140443
# ResNet                                  0.461650
# FTTrans                                      NaN
# boosted_trees                           0.086337
# rf                                      0.146869
# linear_regression                      -0.535444
# engression                              0.058879
#
#                    361293_gower_RMSE_results.csv  \
# Method
# constant                                0.018959
# MLP                                     0.055740
# ResNet                                  0.037618
# FTTrans                                 0.017747
# boosted_trees                           0.023531
# rf                                      0.020379
# linear_regression                       0.057445
# engression                              0.046919
#
#                    361294_gower_RMSE_results.csv
# Method
# constant                                0.952407
# MLP                                     1.861109
# ResNet                                  6.948155
# FTTrans                                 2.919459
# boosted_trees                           3.435455
# rf                                      4.206296
# linear_regression                       3.815673
# engression                              0.520788
#
# [8 rows x 50 columns]
