# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.transforms import Bbox

directory = r'RESULTS/CLUSTERING'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_logloss')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        logloss = table['Log Loss']
        rank = logloss.rank(ascending=True)
        df[task_name] = rank

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rank of test logloss')

# Adding labels and title
plt.xlabel('Method')
plt.title('Clustering')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/clustering_logloss_only_num_features_ranks.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/UMAP_DECOMPOSITION'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_umap_decomposition_logloss')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        logloss = table['Log Loss']
        rank = logloss.rank(ascending=True)
        df[task_name] = rank


df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rank of test logloss')

# Adding labels and title
plt.xlabel('Method')
plt.title('UMAP decomposition')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/umap_decomposition_logloss_only_num_features_ranks.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/SPATIAL_DEPTH'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_spatial_depth_logloss')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        logloss = table['Log Loss']
        rank = logloss.rank(ascending=True)
        df[task_name] = rank

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rank of test logloss')

# Adding labels and title
plt.xlabel('Method')
plt.title('Spatial depth')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/spatial_depth_logloss_only_num_features_ranks.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/MAHALANOBIS'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_mahalanobis_logloss')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        logloss = table['Log Loss']
        rank = logloss.rank(ascending=True)
        df[task_name] = rank

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rank of test logloss')

# Adding labels and title
plt.xlabel('Method')
plt.title('Mahalanobis distance')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/mahalanobis_logloss_only_num_features_ranks.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
# Plotting the average test accuracy for all extrapolation methods
import os
import pandas as pd
import seaborn as sns

list_directories = [r'RESULTS/CLUSTERING', r'RESULTS/UMAP_DECOMPOSITION', r'RESULTS/SPATIAL_DEPTH', r'RESULTS/MAHALANOBIS']
df = pd.DataFrame()

for directory in list_directories:
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            task_name = filename
            filepath = os.path.join(directory, filename)
            table = pd.read_csv(filepath)
            logloss = table['Log Loss']
            rank = logloss.rank(ascending=True)
            df[task_name] = rank

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average rank of test logloss')

# Adding labels and title
plt.xlabel('Method')
plt.title('Average over extrapolation techniques')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/average_over_extrapolation_techniques_logloss_only_num_features_ranks.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
df
# Out:
#                      361055_clustering_logloss_results.csv  \
# Method
# constant                                               8.0
# MLP                                                    4.0
# ResNet                                                 7.0
# FTTrans                                                3.0
# boosted_trees                                          2.0
# rf                                                     1.0
# logistic_regression                                    6.0
# engression                                             5.0
# GAM                                                    9.0
#
#                      361060_clustering_logloss_results.csv  \
# Method
# constant                                               9.0
# MLP                                                    5.0
# ResNet                                                 8.0
# FTTrans                                                2.0
# boosted_trees                                          1.0
# rf                                                     3.0
# logistic_regression                                    6.0
# engression                                             7.0
# GAM                                                    4.0
#
#                      361061_clustering_logloss_results.csv  \
# Method
# constant                                               8.0
# MLP                                                    4.0
# ResNet                                                 7.0
# FTTrans                                                5.0
# boosted_trees                                          1.0
# rf                                                     2.0
# logistic_regression                                    9.0
# engression                                             3.0
# GAM                                                    6.0
#
#                      361062_clustering_logloss_results.csv  \
# Method
# constant                                               8.0
# MLP                                                    4.0
# ResNet                                                 7.0
# FTTrans                                                1.0
# boosted_trees                                          3.0
# rf                                                     5.0
# logistic_regression                                    6.0
# engression                                             2.0
# GAM                                                    NaN
#
#                      361063_clustering_logloss_results.csv  \
# Method
# constant                                               5.0
# MLP                                                    4.0
# ResNet                                                 6.0
# FTTrans                                                2.0
# boosted_trees                                          1.0
# rf                                                     3.0
# logistic_regression                                    8.0
# engression                                             7.0
# GAM                                                    9.0
#
#                      361065_clustering_logloss_results.csv  \
# Method
# constant                                               9.0
# MLP                                                    2.0
# ResNet                                                 7.0
# FTTrans                                                1.0
# boosted_trees                                          3.0
# rf                                                     5.0
# logistic_regression                                    6.0
# engression                                             4.0
# GAM                                                    8.0
#
#                      361066_clustering_logloss_results.csv  \
# Method
# constant                                               9.0
# MLP                                                    4.0
# ResNet                                                 8.0
# FTTrans                                                3.0
# boosted_trees                                          1.0
# rf                                                     2.0
# logistic_regression                                    7.0
# engression                                             6.0
# GAM                                                    5.0
#
#                      361068_clustering_logloss_results.csv  \
# Method
# constant                                               6.0
# MLP                                                    4.0
# ResNet                                                 7.0
# FTTrans                                                1.0
# boosted_trees                                          2.0
# rf                                                     3.0
# logistic_regression                                    8.0
# engression                                             5.0
# GAM                                                    NaN
#
#                      361069_clustering_logloss_results.csv  \
# Method
# constant                                               8.0
# MLP                                                    5.0
# ResNet                                                 7.0
# FTTrans                                                4.0
# boosted_trees                                          1.0
# rf                                                     3.0
# logistic_regression                                    6.0
# engression                                             2.0
# GAM                                                    9.0
#
#                      361070_clustering_logloss_results.csv  ...  \
# Method                                                      ...
# constant                                               4.0  ...
# MLP                                                    6.0  ...
# ResNet                                                 5.0  ...
# FTTrans                                                3.0  ...
# boosted_trees                                          2.0  ...
# rf                                                     1.0  ...
# logistic_regression                                    7.0  ...
# engression                                             8.0  ...
# GAM                                                    9.0  ...
#
#                      361065_mahalanobis_logloss_results.csv  \
# Method
# constant                                                9.0
# MLP                                                     2.0
# ResNet                                                  8.0
# FTTrans                                                 1.0
# boosted_trees                                           3.0
# rf                                                      4.0
# logistic_regression                                     7.0
# engression                                              5.0
# GAM                                                     6.0
#
#                      361066_mahalanobis_logloss_results.csv  \
# Method
# constant                                                9.0
# MLP                                                     4.0
# ResNet                                                  8.0
# FTTrans                                                 2.0
# boosted_trees                                           1.0
# rf                                                      3.0
# logistic_regression                                     6.0
# engression                                              5.0
# GAM                                                     7.0
#
#                      361068_mahalanobis_logloss_results.csv  \
# Method
# constant                                                6.0
# MLP                                                     4.0
# ResNet                                                  8.0
# FTTrans                                                 2.0
# boosted_trees                                           1.0
# rf                                                      3.0
# logistic_regression                                     7.0
# engression                                              5.0
# GAM                                                     NaN
#
#                      361069_mahalanobis_logloss_results.csv  \
# Method
# constant                                                8.0
# MLP                                                     6.0
# ResNet                                                  4.0
# FTTrans                                                 2.0
# boosted_trees                                           1.0
# rf                                                      3.0
# logistic_regression                                     7.0
# engression                                              5.0
# GAM                                                     9.0
#
#                      361070_mahalanobis_logloss_results.csv  \
# Method
# constant                                                4.0
# MLP                                                     7.0
# ResNet                                                  5.0
# FTTrans                                                 3.0
# boosted_trees                                           2.0
# rf                                                      1.0
# logistic_regression                                     6.0
# engression                                              8.0
# GAM                                                     9.0
#
#                      361273_mahalanobis_logloss_results.csv  \
# Method
# constant                                                9.0
# MLP                                                     1.0
# ResNet                                                  4.0
# FTTrans                                                 5.0
# boosted_trees                                           3.0
# rf                                                      6.0
# logistic_regression                                     7.0
# engression                                              2.0
# GAM                                                     8.0
#
#                      361274_mahalanobis_logloss_results.csv  \
# Method
# constant                                                8.0
# MLP                                                     7.0
# ResNet                                                  4.0
# FTTrans                                                 3.0
# boosted_trees                                           1.0
# rf                                                      2.0
# logistic_regression                                     6.0
# engression                                              5.0
# GAM                                                     NaN
#
#                      361275_mahalanobis_logloss_results.csv  \
# Method
# constant                                                4.0
# MLP                                                     6.0
# ResNet                                                  5.0
# FTTrans                                                 3.0
# boosted_trees                                           2.0
# rf                                                      1.0
# logistic_regression                                     7.0
# engression                                              8.0
# GAM                                                     NaN
#
#                      361277_mahalanobis_logloss_results.csv  \
# Method
# constant                                                8.0
# MLP                                                     5.0
# ResNet                                                  7.0
# FTTrans                                                 3.0
# boosted_trees                                           1.0
# rf                                                      2.0
# logistic_regression                                     4.0
# engression                                              6.0
# GAM                                                     NaN
#
#                      361278_mahalanobis_logloss_results.csv
# Method
# constant                                                7.0
# MLP                                                     5.0
# ResNet                                                  8.0
# FTTrans                                                 3.0
# boosted_trees                                           2.0
# rf                                                      1.0
# logistic_regression                                     6.0
# engression                                              4.0
# GAM                                                     NaN
#
# [9 rows x 58 columns]
