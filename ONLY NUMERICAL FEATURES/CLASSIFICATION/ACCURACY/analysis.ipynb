# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

directory = r'RESULTS/CLUSTERING'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        df[task_name] = accuracy

df.index=table['Method']
df.index.name = 'Method'

df.T.boxplot(figsize=(10, 6))
plt.xlabel('Method')
plt.ylabel('Value')
plt.title('Boxplot of DataFrame df')
plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/UMAP_DECOMPOSITION'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        df[task_name] = accuracy

df.index=table['Method']
df.index.name = 'Method'

df.T.boxplot(figsize=(10, 6))
plt.xlabel('Method')
plt.ylabel('Value')
plt.title('Boxplot of DataFrame df')
plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/SPATIAL_DEPTH'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        df[task_name] = accuracy

df.index=table['Method']
df.index.name = 'Method'

df.T.boxplot(figsize=(10, 6))
plt.xlabel('Method')
plt.ylabel('Value')
plt.title('Boxplot of DataFrame df')
plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/MAHALANOBIS'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        df[task_name] = accuracy

df.index=table['Method']
df.index.name = 'Method'

df.T.boxplot(figsize=(10, 6))
plt.xlabel('Method')
plt.ylabel('Value')
plt.title('Boxplot of DataFrame df')
plt.show()
