# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.transforms import Bbox
import numpy as np

directory = r'RESULTS/CLUSTERING'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        highest_accuracy = np.nanmax(accuracy)
        df[task_name] = (highest_accuracy - accuracy) / highest_accuracy

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['Constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'GP', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average relative difference to the best test accuracy (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Clustering')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure

# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/clustering_accuracy_only_num_features_relative_differences.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/UMAP_DECOMPOSITION'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_umap_decomposition_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)      
        accuracy = table['Accuracy']
        highest_accuracy = np.nanmax(accuracy)
        df[task_name] = (highest_accuracy - accuracy) / highest_accuracy

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['Constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'GP', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average relative difference to the best test accuracy (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('UMAP decomposition')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/umap_decomposition_accuracy_only_num_features_relative_differences.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/SPATIAL_DEPTH'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_spatial_depth_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        highest_accuracy = np.nanmax(accuracy)
        df[task_name] = (highest_accuracy - accuracy) / highest_accuracy

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['Constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'GP', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average relative difference to the best test accuracy (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Spatial depth')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/spatial_depth_accuracy_only_num_features_relative_differences.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/MAHALANOBIS'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_mahalanobis_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath)
        accuracy = table['Accuracy']
        highest_accuracy = np.nanmax(accuracy)
        df[task_name] = (highest_accuracy - accuracy) / highest_accuracy

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['Constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'GP', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average relative difference to the best test accuracy (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Mahalanobis distance')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/mahalanobis_accuracy_only_num_features_relative_differences.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
# Plotting the average test accuracy for all extrapolation methods
import os
import pandas as pd
import seaborn as sns

list_directories = [r'RESULTS/CLUSTERING', r'RESULTS/UMAP_DECOMPOSITION', r'RESULTS/SPATIAL_DEPTH', r'RESULTS/MAHALANOBIS']
df = pd.DataFrame()

for directory in list_directories:
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            task_name = filename
            filepath = os.path.join(directory, filename)
            table = pd.read_csv(filepath) 
            accuracy = table['Accuracy']
            highest_accuracy = np.nanmax(accuracy)
            df[task_name] = (highest_accuracy - accuracy) / highest_accuracy

df.index=table['Method']
df.index.name = 'Method'
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)

# Reorder the methods
method_order = ['Constant', 'logistic_regression', 'GAM', 'rf', 'boosted_trees', 'GP', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)

# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)

result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})
result_df['Mean'] = 100*result_df['Mean']

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')

# Removing the ylabel
plt.ylabel('Average relative difference to the best test accuracy (in %)')

# Adding labels and title
plt.xlabel('Method')
plt.title('Average over extrapolation techniques')

# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')

# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure


# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/average_over_extrapolation_techniques_accuracy_only_num_features_relative_differences.png',bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))

plt.show()

# %%
df
# Out:
#                      361055_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.485323
# MLP                                                0.019080
# ResNet                                             0.293542
# FTTrans                                            0.026908
# boosted_trees                                      0.000000
# rf                                                 0.009295
# logistic_regression                                0.057730
# engression                                         0.048434
# GAM                                                0.080235
#
#                      361060_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.578032
# MLP                                                0.024256
# ResNet                                             0.164760
# FTTrans                                            0.019222
# boosted_trees                                      0.010526
# rf                                                 0.000000
# logistic_regression                                0.025629
# engression                                         0.005492
# GAM                                                0.006865
#
#                      361061_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.472131
# MLP                                                0.018443
# ResNet                                             0.127869
# FTTrans                                            0.026230
# boosted_trees                                      0.000000
# rf                                                 0.004098
# logistic_regression                                0.304918
# engression                                         0.077459
# GAM                                                0.036885
#
#                      361062_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.844221
# MLP                                                0.001005
# ResNet                                             0.358794
# FTTrans                                            0.003015
# boosted_trees                                      0.005528
# rf                                                 0.010553
# logistic_regression                                0.291457
# engression                                         0.000000
# GAM                                                     NaN
#
#                      361063_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.404235
# MLP                                                0.030588
# ResNet                                             0.294588
# FTTrans                                            0.040000
# boosted_trees                                      0.002824
# rf                                                 0.031529
# logistic_regression                                0.201882
# engression                                         0.000000
# GAM                                                0.137882
#
#                      361065_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.799566
# MLP                                                0.004772
# ResNet                                             0.498915
# FTTrans                                            0.014317
# boosted_trees                                      0.025163
# rf                                                 0.066377
# logistic_regression                                0.137527
# engression                                         0.000000
# GAM                                                0.190022
#
#                      361066_clustering_accuracy_results.csv  \
# Method
# Constant                                             0.5620
# MLP                                                  0.0310
# ResNet                                               0.3180
# FTTrans                                              0.0115
# boosted_trees                                        0.0000
# rf                                                   0.0220
# logistic_regression                                  0.1310
# engression                                           0.0465
# GAM                                                  0.1355
#
#                      361068_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.779168
# MLP                                                0.000000
# ResNet                                             0.779168
# FTTrans                                            0.010900
# boosted_trees                                      0.016956
# rf                                                 0.051272
# logistic_regression                                0.274122
# engression                                         0.009689
# GAM                                                     NaN
#
#                      361069_clustering_accuracy_results.csv  \
# Method
# Constant                                           0.377704
# MLP                                                0.009151
# ResNet                                             0.128536
# FTTrans                                            0.069884
# boosted_trees                                      0.000416
# rf                                                 0.000000
# logistic_regression                                0.130616
# engression                                         0.009151
# GAM                                                0.079867
#
#                      361070_clustering_accuracy_results.csv  ...  \
# Method                                                       ...
# Constant                                           0.211946  ...
# MLP                                                0.127168  ...
# ResNet                                             0.172447  ...
# FTTrans                                            0.083815  ...
# boosted_trees                                      0.000000  ...
# rf                                                 0.057803  ...
# logistic_regression                                0.129094  ...
# engression                                         0.096339  ...
# GAM                                                0.107900  ...
#
#                      361065_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.811080
# MLP                                                 0.000000
# ResNet                                              0.470307
# FTTrans                                             0.014348
# boosted_trees                                       0.009964
# rf                                                  0.025508
# logistic_regression                                 0.144281
# engression                                          0.001594
# GAM                                                 0.066162
#
#                      361066_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.620614
# MLP                                                 0.030702
# ResNet                                              0.265351
# FTTrans                                             0.000000
# boosted_trees                                       0.004386
# rf                                                  0.008224
# logistic_regression                                 0.125548
# engression                                          0.026316
# GAM                                                 0.020833
#
#                      361068_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.617805
# MLP                                                 0.006078
# ResNet                                              0.618162
# FTTrans                                             0.023954
# boosted_trees                                       0.012871
# rf                                                  0.042903
# logistic_regression                                 0.111548
# engression                                          0.000000
# GAM                                                      NaN
#
#                      361069_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.382625
# MLP                                                 0.043900
# ResNet                                              0.085490
# FTTrans                                             0.001848
# boosted_trees                                       0.000000
# rf                                                  0.018484
# logistic_regression                                 0.082717
# engression                                          0.030037
# GAM                                                 0.114603
#
#                      361070_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.228571
# MLP                                                 0.123469
# ResNet                                              0.210204
# FTTrans                                             0.104082
# boosted_trees                                       0.000000
# rf                                                  0.068367
# logistic_regression                                 0.140816
# engression                                          0.168367
# GAM                                                 0.165306
#
#                      361273_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.254450
# MLP                                                 0.022513
# ResNet                                              0.000000
# FTTrans                                             0.047644
# boosted_trees                                       0.021466
# rf                                                  0.017801
# logistic_regression                                 0.038743
# engression                                          0.002618
# GAM                                                 0.039791
#
#                      361274_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.421992
# MLP                                                 0.074274
# ResNet                                              0.082573
# FTTrans                                             0.052697
# boosted_trees                                       0.000000
# rf                                                  0.016183
# logistic_regression                                 0.103734
# engression                                          0.034025
# GAM                                                      NaN
#
#                      361275_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.390369
# MLP                                                 0.067623
# ResNet                                              0.342725
# FTTrans                                             0.022029
# boosted_trees                                       0.025615
# rf                                                  0.000000
# logistic_regression                                 0.092725
# engression                                          0.075307
# GAM                                                      NaN
#
#                      361277_mahalanobis_accuracy_results.csv  \
# Method
# Constant                                            0.497760
# MLP                                                 0.024272
# ResNet                                              0.106049
# FTTrans                                             0.024645
# boosted_trees                                       0.000000
# rf                                                  0.012323
# logistic_regression                                 0.057506
# engression                                          0.028753
# GAM                                                      NaN
#
#                      361278_mahalanobis_accuracy_results.csv
# Method
# Constant                                            0.442829
# MLP                                                 0.017845
# ResNet                                              0.247852
# FTTrans                                             0.051553
# boosted_trees                                       0.015202
# rf                                                  0.015863
# logistic_regression                                 0.058824
# engression                                          0.000000
# GAM                                                      NaN
#
# [9 rows x 58 columns]
