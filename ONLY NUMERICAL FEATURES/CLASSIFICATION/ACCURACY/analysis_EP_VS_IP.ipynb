# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.transforms import Bbox
import numpy as np

directory = r'RESULTS/CLUSTERING'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_clustering_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        accuracy = table['Accuracy']
        filepath_random = os.path.join(directory_random, task_name + '_random_accuracy_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        accuracy_random = table_random['Accuracy']
        df[task_name] = (accuracy_random - accuracy) / accuracy_random

df.index=table['Method']
df.index.name = 'Method'
df=100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)
# Reorder the methods
method_order = ['Constant', 'logistic_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)
# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)
result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')
# Removing the ylabel
plt.ylabel('Average rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Clustering')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/clustering_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Median', color='black')
# Removing the ylabel
plt.ylabel('Median rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Clustering')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/median_clustering_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/UMAP_DECOMPOSITION'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_umap_decomposition_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]      
        accuracy = table['Accuracy']
        filepath_random = os.path.join(directory_random, task_name + '_random_accuracy_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        accuracy_random = table_random['Accuracy']
        df[task_name] = (accuracy_random - accuracy) / accuracy_random

df.index=table['Method']
df.index.name = 'Method'
df=100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)
# Reorder the methods
method_order = ['Constant', 'logistic_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)
# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)
result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')
# Removing the ylabel
plt.ylabel('Average rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('UMAP decomposition')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/umap_decomposition_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Median', color='black')
# Removing the ylabel
plt.ylabel('Median rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('UMAP decomposition')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/median_umap_decomposition_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# %%
import os
import pandas as pd

directory = r'RESULTS/SPATIAL_DEPTH'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_spatial_depth_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        accuracy = table['Accuracy']
        filepath_random = os.path.join(directory_random, task_name + '_random_accuracy_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        accuracy_random = table_random['Accuracy']
        df[task_name] = (accuracy_random - accuracy) / accuracy_random

df.index=table['Method']
df.index.name = 'Method'
df=100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)
# Reorder the methods
method_order = ['Constant', 'logistic_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)
# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)
result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')
# Removing the ylabel
plt.ylabel('Average rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Spatial depth')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/spatial_depth_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Median', color='black')
# Removing the ylabel
plt.ylabel('Median rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Spatial depth')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/median_spatial_depth_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# %%
result_df
# Out:
#                 Method       Mean     Median  Standard Deviation
# 0             constant  18.657095  10.169492           24.216160
# 6  logistic regression   0.183167  -0.689655            4.701963
# 5        random forest  -0.351034   0.659229            4.572909
# 4        boosted trees  -0.476447  -0.401204            4.086649
# 7           engression   0.150062   0.761615            5.108879
# 1                  MLP   0.313478   0.719770            5.119129
# 2               ResNet  21.832937  20.502092           18.587613
# 3       FT-Transformer  -0.348580  -0.355556            4.563322

# %%
import os
import pandas as pd

directory = r'RESULTS/MAHALANOBIS'
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()

for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        task_name = filename.split('_mahalanobis_accuracy')[0]
        filepath = os.path.join(directory, filename)
        table = pd.read_csv(filepath).iloc[:-2, :]
        accuracy = table['Accuracy']
        filepath_random = os.path.join(directory_random, task_name + '_random_accuracy_results.csv')
        table_random = pd.read_csv(filepath_random).iloc[:-2, :]
        accuracy_random = table_random['Accuracy']
        df[task_name] = (accuracy_random - accuracy) / accuracy_random

df.index=table['Method']
df.index.name = 'Method'
df=100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)
# Reorder the methods
method_order = ['Constant', 'logistic_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)
# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)
result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')
# Removing the ylabel
plt.ylabel('Average rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Mahalanobis distance')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/mahalanobis_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Median', color='black')
# Removing the ylabel
plt.ylabel('Median rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Mahalanobis distance')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/median_mahalanobis_accuracy_only_num_features_EP_VS_IP.png', bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# %%
# Plotting the average test accuracy for all extrapolation methods
import os
import pandas as pd
import seaborn as sns

list_directories = [r'RESULTS/CLUSTERING', r'RESULTS/UMAP_DECOMPOSITION', r'RESULTS/SPATIAL_DEPTH', r'RESULTS/MAHALANOBIS', r'RESULTS/GOWER', r'RESULTS/K_MEDOIDS', r'RESULTS/UMAP_DECOMPOSITION_CAT']
directory_random = r'RESULTS/RANDOM'
df = pd.DataFrame()
for directory in list_directories:
    if directory in [r'RESULTS/CLUSTERING', r'RESULTS/UMAP_DECOMPOSITION', r'RESULTS/SPATIAL_DEPTH', r'RESULTS/MAHALANOBIS']:
        directory_random = r'RESULTS/RANDOM'
    else:
        directory_random = r'RESULTS/RANDOM_CAT'
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            task_name = filename
            filepath = os.path.join(directory, filename)
            table = pd.read_csv(filepath).iloc[:-2, :] 
            accuracy = table['Accuracy']
            task_name_2 = filename.split('_')[0]
            filepath_random = os.path.join(directory_random, task_name_2 + '_random_accuracy_results.csv')
            table_random = pd.read_csv(filepath_random).iloc[:-2, :]
            accuracy_random = table_random['Accuracy']
            df[task_name] = (accuracy_random - accuracy) / accuracy_random

df.index=table['Method']
df.index.name = 'Method'
df=100*df
mean = df.mean(axis=1)
median = df.median(axis=1)
std = df.std(axis=1)
result_df = pd.DataFrame({'Mean': mean, 'Median': median, 'Standard Deviation': std})
result_df.index.name = 'Method'
result_df.reset_index(inplace=True)
# Reorder the methods
method_order = ['Constant', 'logistic_regression',  'rf', 'boosted_trees', 'engression', 'MLP', 'ResNet', 'FTTrans']
result_df['Method'] = pd.Categorical(result_df['Method'], categories=method_order, ordered=True)
# Sort the dataframe by the reordered method column
result_df.sort_values('Method', inplace=True)
result_df['Method'] = result_df['Method'].replace({'Constant': 'constant', 'rf': 'random forest', 'boosted_trees': 'boosted trees', 'logistic_regression': 'logistic regression', 'FTTrans': 'FT-Transformer'})

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Mean', color='black')
# Removing the ylabel
plt.ylabel('Average rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Average over extrapolation techniques')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/average_over_extrapolation_techniques_accuracy_only_num_features_EP_VS_IP.png',bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# Plot the scatterplot
sns.scatterplot(data=result_df, x='Method', y='Median', color='black')
# Removing the ylabel
plt.ylabel('Median rel. difference to random split test accuracy (in %)')
# Adding labels and title
plt.xlabel('Method')
plt.title('Average over extrapolation techniques')
# Rotating x-axis labels vertically
plt.xticks(rotation=45, ha='right')
# Set the figure size
fig = plt.gcf()  # Get the current figure
fig_size = fig.get_size_inches()  # Get the size of the figure
# Save the plot
os.makedirs('PICTURES', exist_ok=True)
plt.savefig('PICTURES/median_average_over_extrapolation_techniques_accuracy_only_num_features_EP_VS_IP.png',bbox_inches=Bbox([[0,-1], [fig_size[0], fig_size[1]]]))
plt.show()

# %%
result_df
# Out:
#                 Method       Mean     Median  Standard Deviation
# 0             constant  17.847228  11.007338           20.186983
# 6  logistic regression   0.766555   0.062657            6.088630
# 5        random forest   0.991769   0.367962            7.247688
# 4        boosted trees   1.852531   0.610820            8.867901
# 7           engression   1.307268   1.069519            6.146123
# 1                  MLP   0.763040   0.249104            5.722701
# 2               ResNet  18.511579  13.898115           16.425954
# 3       FT-Transformer   0.770252   0.021268            6.148543
